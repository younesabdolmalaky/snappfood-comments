# %%
import pandas as pd

# %%
data = pd.read_csv('../datasets/Snappfood - Sentiment Analysis.csv' , on_bad_lines='skip' , delimiter='\t')
data.head(50)
# Out:
#                                    Unnamed: 0  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21   هزار پول ساندویچ شد، ولی بیشترش قارچ بود
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                        NaN
# 45                                        NaN
# 46                                        NaN
# 47                                        NaN
# 48                                        NaN
# 49                                        NaN
#
#                                               comment  label  label_id
# 0     واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح    SAD       1.0
# 1   قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...  HAPPY       0.0
# 2   قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...    SAD       1.0
# 3   عالللی بود همه چه درست و به اندازه و کیفیت خوب...  HAPPY       0.0
# 4                       شیرینی وانیلی فقط یک مدل بود.  HAPPY       0.0
# 5              بدترین پیتزایی که تا به حال خورده بودم    SAD       1.0
# 6                             از همه لحاظ عالی ممنونم  HAPPY       0.0
# 7   کیفیت غذا متوسط رو به پایین بود انگار داخل یه ...    SAD       1.0
# 8   همه اقلام تازه و به روز وخیلیییییی سریع بدستم ...  HAPPY       0.0
# 9   همه چی خوب ولی هات داگ دورش کلا سوخته بود و دا...    SAD       1.0
# 10  اکلر فوق العاده بود اما بافت چیزکیک مونده بود ...  HAPPY       0.0
# 11    خوب بود و از رستوران غنچه و اسنپ فود تشکر میکنم  HAPPY       0.0
# 12  مثل همیشه عااااالی هستی پرپروک جاااااان مچکریم...  HAPPY       0.0
# 13                       Kheili khub bud mersi vaghan  HAPPY       0.0
# 14  عکس با شیریبی که ارسال کردند فرق داشت و خیلی ن...    SAD       1.0
# 15              سریع سفارش بدستم رسید ممنونم اسنپ فود  HAPPY       0.0
# 16              خیلی عالی بود خیلی هم زود رسید خوشمزه  HAPPY       0.0
# 17                  هات داگ یکم خام بود. حجمش خوب بود  HAPPY       0.0
# 18   ممنون که به صلاحدید هودتون سفارش رو تغییر دادید.    SAD       1.0
# 19  پیتزا سرد و خیلی خیلی بدمزه بود و میگوتون افتض...    SAD       1.0
# 20  خیلی مسخرس یک ساعت باید منتظر موند و تازه ۳ هز...    SAD       1.0
# 21                                                SAD      1       NaN
# 22  سفارش من رانی آناناس بود ولی مغازه سانی نس آنا...    SAD       1.0
# 23  سلام. خیلی عالیه. متشکرم. همیشه در کارتان موفق...  HAPPY       0.0
# 24  سفارش پس از تاخیر بسیار طولانی رسید و متاسفانه...    SAD       1.0
# 25  بسیار عالی و به موقع رسید طعم و کیفیت هم عالی بود  HAPPY       0.0
# 26                  مثل دفعه قبل هم به موقع هم خوشمزه  HAPPY       0.0
# 27  کیفیت غذا خوب بود و تقریبا داغ بود اما خیلی دی...  HAPPY       0.0
# 28  بد نبود اما برخلاف دفعات قبل چرب‌تر بود و بال ...    SAD       1.0
# 29     من فقط یه سیب زمینی سفارش دادم ۲ ساعت طول کشید    SAD       1.0
# 30  سریع و زودتر از تایم اعلامی بدستم رسید و این خ...  HAPPY       0.0
# 31                       بسیار تازه و خوشمزه بود مرسی  HAPPY       0.0
# 32  سس ۴۸۵گرمی سفارش دادن، اما سس ۴۵۵گرمی برام آوردن!    SAD       1.0
# 33  نوشابه ارسال نشد، با این که هزینه آن پرداخت شد...    SAD       1.0
# 34                           سلام بسیار خوب بود ممنون  HAPPY       0.0
# 35  دستتون درد نکنه عالی بود هم حجمش از لحاظ قیمت ...  HAPPY       0.0
# 36  سریع و به موقع با اجناس عالی و تاریخ مصرف درست...  HAPPY       0.0
# 37  اصلا دانمارکی نبود بسیار بیات و مونده بود اصلا...    SAD       1.0
# 38  بجای ۱۰ عدد پای سیب. سه عدد مدل متفاوت با سفار...    SAD       1.0
# 39  کیسه زیپ دار سفارش دادم، کیسه معمولی برای من ف...    SAD       1.0
# 40                      سریع‌تر و با کیفیت بیشتد تشکر  HAPPY       0.0
# 41  بسیار عالی و با کیفیت، ممنونم و امیدوارم که ای...  HAPPY       0.0
# 42  به شدت چرب بود و اصلا مزه چیزی بجز روغن احساس ...    SAD       1.0
# 43                               غذای این سری خوب بود  HAPPY       0.0
# 44                             عالی خیلی هم سریع رسید  HAPPY       0.0
# 45  کیک و جعبه ان متلاشی شده بود. که پیک زمان تحوی...    SAD       1.0
# 46  غذا بسیار دیر تحویل داده شد و فقط نون و پنیر بود.    SAD       1.0
# 47                              مرغ کامل سرخ نشده بود    SAD       1.0
# 48  طعم ابگوشت تلخ بود و اب ابگوشت خیلی کم بود و ک...    SAD       1.0
# 49                                 کیفت چلو پایین بود    SAD       1.0

# %%
data = data[['comment' , 'label' , 'label_id']]

# %%
data['comment'].str.replace(['a'],'')[13]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 data['comment'].str.replace(['a'],'')[13]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py:1500, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1497 if case is None:
#    1498     case = True
# -> 1500 result = self._data.array._str_replace(
#    1501     pat, repl, n=n, case=case, flags=flags, regex=regex
#    1502 )
#    1503 return self._wrap_result(result)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/strings/object_array.py:158, in ObjectStringArrayMixin._str_replace(self, pat, repl, n, case, flags, regex)
#     156     if regex is False:
#     157         pat = re.escape(pat)
# --> 158     pat = re.compile(pat, flags=flags)
#     160 n = n if n >= 0 else 0
#     161 f = lambda x: pat.sub(repl=repl, string=x, count=n)
#
# File /usr/lib/python3.10/re.py:251, in compile(pattern, flags)
#     249 def compile(pattern, flags=0):
#     250     "Compile a regular expression pattern, returning a Pattern object."
# --> 251     return _compile(pattern, flags)
#
# File /usr/lib/python3.10/re.py:293, in _compile(pattern, flags)
#     291     flags = flags.value
#     292 try:
# --> 293     return _cache[type(pattern), pattern, flags]
#     294 except KeyError:
#     295     pass
#
# TypeError: unhashable type: 'list'
